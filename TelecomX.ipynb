# %% [markdown]
# <a href="https://colab.research.google.com/github/xsaravix/TelecomX/blob/main/TelecomX.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #📌 Extracão

# %% [markdown]
# Importando as bibliotecas

# %%
import pandas as pd
import requests
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go

# %% [markdown]
# Leitura, normalização e limpeza dos dados

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/challenge2-data-science/refs/heads/main/TelecomX_Data.json'

# %%
response = requests.get(url)
data = response.json()

dados = pd.DataFrame(data)

# %%
dados.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
from pandas import json_normalize

dados_normalizados = json_normalize(data)
dados_normalizados.head()
# Out:
#    customerID Churn customer.gender  customer.SeniorCitizen customer.Partner  \
# 0  0002-ORFBO    No          Female                       0              Yes
# 1  0003-MKNFE    No            Male                       0               No
# 2  0004-TLHLJ   Yes            Male                       0               No
# 3  0011-IGKFF   Yes            Male                       1              Yes
# 4  0013-EXCHZ   Yes          Female                       1              Yes
#
#   customer.Dependents  customer.tenure phone.PhoneService phone.MultipleLines  \
# 0                 Yes                9                Yes                  No
# 1                  No                9                Yes                 Yes
# 2                  No                4                Yes                  No
# 3                  No               13                Yes                  No
# 4                  No                3                Yes                  No
#
# ...

# %% [markdown]
# #🔧 Transformação

# %% [markdown]
# Verificando inconsistências

# %%
dados_normalizados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   object
#  2   customer.gender            7267 non-null   object
#  3   customer.SeniorCitizen     7267 non-null   int64
#  4   customer.Partner           7267 non-null   object
#  5   customer.Dependents        7267 non-null   object
#  6   customer.tenure            7267 non-null   int64
#  7   phone.PhoneService         7267 non-null   object
#  8   phone.MultipleLines        7267 non-null   object
#  9   internet.InternetService   7267 non-null   object
#  10  internet.OnlineSecurity    7267 non-null   object
#  11  internet.OnlineBackup      7267 non-null   object
#  12  internet.DeviceProtection  7267 non-null   object
# ...

# %%
dados_normalizados.isnull().sum()
# Out:
# customerID                   0
# Churn                        0
# customer.gender              0
# customer.SeniorCitizen       0
# customer.Partner             0
# customer.Dependents          0
# customer.tenure              0
# phone.PhoneService           0
# phone.MultipleLines          0
# internet.InternetService     0
# internet.OnlineSecurity      0
# internet.OnlineBackup        0
# internet.DeviceProtection    0
# internet.TechSupport         0
# internet.StreamingTV         0
# internet.StreamingMovies     0
# account.Contract             0
# account.PaperlessBilling     0
# account.PaymentMethod        0
# account.Charges.Monthly      0
# account.Charges.Total        0
# dtype: int64

# %%
for coluna in dados_normalizados.columns:
  print(f'{coluna}: {dados_normalizados[coluna].unique()}')
# Out:
# customerID: ['0002-ORFBO' '0003-MKNFE' '0004-TLHLJ' ... '9992-UJOEL' '9993-LHIEB'
#  '9995-HOTOH']
# Churn: ['No' 'Yes' '']
# customer.gender: ['Female' 'Male']
# customer.SeniorCitizen: [0 1]
# customer.Partner: ['Yes' 'No']
# customer.Dependents: ['Yes' 'No']
# customer.tenure: [ 9  4 13  3 71 63  7 65 54 72  5 56 34  1 45 50 23 55 26 69 11 37 49 66
#  67 20 43 59 12 27  2 25 29 14 35 64 39 40  6 30 70 57 58 16 32 33 10 21
#  61 15 44 22 24 19 47 62 46 52  8 60 48 28 41 53 68 51 31 36 17 18 38 42
#   0]
# phone.PhoneService: ['Yes' 'No']
# phone.MultipleLines: ['No' 'Yes' 'No phone service']
# internet.InternetService: ['DSL' 'Fiber optic' 'No']
# internet.OnlineSecurity: ['No' 'Yes' 'No internet service']
# internet.OnlineBackup: ['Yes' 'No' 'No internet service']
# internet.DeviceProtection: ['No' 'Yes' 'No internet service']
# internet.TechSupport: ['Yes' 'No' 'No internet service']
# internet.StreamingTV: ['Yes' 'No' 'No internet service']
# ...

# %%
dados_normalizados.duplicated().sum()
# Out:
# np.int64(0)

# %%
dados_normalizados.apply(lambda x: x.astype(str).str.strip() == '').sum()
# Out:
# customerID                     0
# Churn                        224
# customer.gender                0
# customer.SeniorCitizen         0
# customer.Partner               0
# customer.Dependents            0
# customer.tenure                0
# phone.PhoneService             0
# phone.MultipleLines            0
# internet.InternetService       0
# internet.OnlineSecurity        0
# internet.OnlineBackup          0
# internet.DeviceProtection      0
# internet.TechSupport           0
# internet.StreamingTV           0
# internet.StreamingMovies       0
# account.Contract               0
# account.PaperlessBilling       0
# account.PaymentMethod          0
# account.Charges.Monthly        0
# account.Charges.Total         11
# dtype: int64

# %% [markdown]
# Tratando as inconsistências

# %%
dados_normalizados.columns = dados_normalizados.columns.str.replace('.', '_', regex=False)

# %%
dados_normalizados.head()
# Out:
#    customerID Churn customer_gender  customer_SeniorCitizen customer_Partner  \
# 0  0002-ORFBO    No          Female                       0              Yes
# 1  0003-MKNFE    No            Male                       0               No
# 2  0004-TLHLJ   Yes            Male                       0               No
# 3  0011-IGKFF   Yes            Male                       1              Yes
# 4  0013-EXCHZ   Yes          Female                       1              Yes
#
#   customer_Dependents  customer_tenure phone_PhoneService phone_MultipleLines  \
# 0                 Yes                9                Yes                  No
# 1                  No                9                Yes                 Yes
# 2                  No                4                Yes                  No
# 3                  No               13                Yes                  No
# 4                  No                3                Yes                  No
#
# ...

# %%
churn_desconhecido = dados_normalizados.query('Churn == ""')

# %%
churn_desconhecido.head()
# Out:
#      customerID Churn customer_gender  customer_SeniorCitizen  \
# 30   0047-ZHDTW                Female                       0
# 75   0120-YZLQA                  Male                       0
# 96   0154-QYHJU                  Male                       0
# 98   0162-RZGMZ                Female                       1
# 175  0274-VVQOQ                  Male                       1
#
#     customer_Partner customer_Dependents  customer_tenure phone_PhoneService  \
# 30                No                  No               11                Yes
# 75                No                  No               71                Yes
# 96                No                  No               29                Yes
# 98                No                  No                5                Yes
# 175              Yes                  No               65                Yes
#
#     phone_MultipleLines internet_InternetService  ... internet_OnlineBackup  \
# ...

# %%
churn_desconhecido.tail()
# Out:
#       customerID Churn customer_gender  customer_SeniorCitizen  \
# 7158  9840-GSRFX                Female                       0
# 7180  9872-RZQQB                Female                       0
# 7211  9920-GNDMB                  Male                       0
# 7239  9955-RVWSC                Female                       0
# 7247  9966-VYRTZ                Female                       0
#
#      customer_Partner customer_Dependents  customer_tenure phone_PhoneService  \
# 7158               No                  No               14                Yes
# 7180              Yes                  No               49                 No
# 7211               No                  No                9                Yes
# 7239              Yes                 Yes               67                Yes
# 7247              Yes                 Yes               31                Yes
#
#      phone_MultipleLines internet_InternetService  ... internet_OnlineBackup  \
# ...

# %%
# Removendo as linhas onde Churn está sem valor
dados_normalizados = dados_normalizados[dados_normalizados['Churn'].str.strip() != '']

# %%
#Alterando a coluna "account.Charges.Total" para Float

dados_normalizados['account_Charges_Total'] = pd.to_numeric(dados_normalizados['account_Charges_Total'], errors='coerce')
dados_normalizados['account_Charges_Total'].dtype
# Out:
# /tmp/ipython-input-17-2795916313.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_normalizados['account_Charges_Total'] = pd.to_numeric(dados_normalizados['account_Charges_Total'], errors='coerce')
# dtype('float64')

# %%
dados_normalizados.apply(lambda x: x.astype(str).str.strip() == '').sum()
# Out:
# customerID                   0
# Churn                        0
# customer_gender              0
# customer_SeniorCitizen       0
# customer_Partner             0
# customer_Dependents          0
# customer_tenure              0
# phone_PhoneService           0
# phone_MultipleLines          0
# internet_InternetService     0
# internet_OnlineSecurity      0
# internet_OnlineBackup        0
# internet_DeviceProtection    0
# internet_TechSupport         0
# internet_StreamingTV         0
# internet_StreamingMovies     0
# account_Contract             0
# account_PaperlessBilling     0
# account_PaymentMethod        0
# account_Charges_Monthly      0
# account_Charges_Total        0
# dtype: int64

# %% [markdown]
# Analisando colunas para entender a importância das variáveis na análise e fazer possíveis remoções

# %%
dados_normalizados
# Out:
#       customerID Churn customer_gender  customer_SeniorCitizen  \
# 0     0002-ORFBO    No          Female                       0
# 1     0003-MKNFE    No            Male                       0
# 2     0004-TLHLJ   Yes            Male                       0
# 3     0011-IGKFF   Yes            Male                       1
# 4     0013-EXCHZ   Yes          Female                       1
# ...          ...   ...             ...                     ...
# 7262  9987-LUTYD    No          Female                       0
# 7263  9992-RRAMN   Yes            Male                       0
# 7264  9992-UJOEL    No            Male                       0
# 7265  9993-LHIEB    No            Male                       0
# 7266  9995-HOTOH    No            Male                       0
#
#      customer_Partner customer_Dependents  customer_tenure phone_PhoneService  \
# 0                 Yes                 Yes                9                Yes
# ...

# %%
dados_normalizados = dados_normalizados.drop(['customerID'], axis=1)

# %%
dados_normalizados.reset_index(drop=True, inplace=True)

# %%
dados_normalizados = dados_normalizados.replace('Yes', 1)
dados_normalizados = dados_normalizados.replace('No', 0)
# Out:
# /tmp/ipython-input-22-2734015794.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dados_normalizados = dados_normalizados.replace('No', 0)

# %%
dados_normalizados.head()
# Out:
#    Churn customer_gender  customer_SeniorCitizen  customer_Partner  \
# 0      0          Female                       0                 1
# 1      0            Male                       0                 0
# 2      1            Male                       0                 0
# 3      1            Male                       1                 1
# 4      1          Female                       1                 1
#
#    customer_Dependents  customer_tenure  phone_PhoneService  \
# 0                    1                9                   1
# 1                    0                9                   1
# 2                    0                4                   1
# 3                    0               13                   1
# 4                    0                3                   1
#
#   phone_MultipleLines internet_InternetService internet_OnlineSecurity  \
# 0                   0                      DSL                       0
# ...

# %%
dados_normalizados['contas_diarias'] = (dados_normalizados['account_Charges_Monthly'] / 30).round(2)
dados_normalizados.head()
# Out:
#    Churn customer_gender  customer_SeniorCitizen  customer_Partner  \
# 0      0          Female                       0                 1
# 1      0            Male                       0                 0
# 2      1            Male                       0                 0
# 3      1            Male                       1                 1
# 4      1          Female                       1                 1
#
#    customer_Dependents  customer_tenure  phone_PhoneService  \
# 0                    1                9                   1
# 1                    0                9                   1
# 2                    0                4                   1
# 3                    0               13                   1
# 4                    0                3                   1
#
#   phone_MultipleLines internet_InternetService internet_OnlineSecurity  ...  \
# 0                   0                      DSL                       0  ...
# ...

# %%
dados_normalizados = dados_normalizados.rename(columns={'customer_gender': 'genero', 'customer_SeniorCitizen': 'idoso', 'customer_Partner': 'parceiro',
                                                        'customer_Dependents': 'dependentes', 'customer_tenure': 'meses_contrato', 'phone_PhoneService': 'servico_telefonico',
                                                        'phone_MultipleLines': 'multiplas_linhas', 'internet_InternetService': 'servico_internet',
                                                        'internet_OnlineSecurity': 'seguranca_online', 'internet_OnlineBackup': 'backup_online',
                                                        'internet_DeviceProtection': 'protecao_dispositivo', 'internet_TechSupport': 'suporte_tecnico',
                                                        'internet_StreamingTV': 'tv_a_cabo', 'internet_StreamingMovies': 'streaming_filmes',
                                                        'account_Contract': 'contrato', 'account_PaperlessBilling': 'fatura_online', 'account_PaymentMethod': 'metodo_pagamento',
                                                        'account_Charges_Monthly': 'cobranca_mensal', 'account_Charges_Total': 'gasto_total'})
dados_normalizados.head(10)
# Out:
#    Churn  genero  idoso  parceiro  dependentes  meses_contrato  \
# 0      0  Female      0         1            1               9
# 1      0    Male      0         0            0               9
# 2      1    Male      0         0            0               4
# 3      1    Male      1         1            0              13
# 4      1  Female      1         1            0               3
# 5      0  Female      0         0            1               9
# 6      0  Female      1         1            0              71
# 7      0    Male      0         1            0              63
# 8      0  Female      1         0            0               7
# 9      0  Female      0         1            1              65
#
#    servico_telefonico multiplas_linhas servico_internet seguranca_online  ...  \
# 0                   1                0              DSL                0  ...
# 1                   1                1              DSL                0  ...
# ...

# %%
substituicoes = {
    'Male': 'masculino',
    'Female': 'feminino',
    'Month-to-month': 'mensal',
    'One year': 'anual',
    'Two year': 'bienal',
    'Fiber optic': 'fibra óptica',
    'Mailed check': 'cheque',
    'Electronic check': 'cheque eletrônico',
    'Credit card (automatic)': 'cartão de crédito automático',
    'Bank transfer (automatic)': 'transferência bancária automática',
    'No phone service': 'sem serviço telefônico',
    'No internet service': 'sem serviço de internet'
}

dados_normalizados.replace(substituicoes, inplace=True)

# %%
dados_normalizados.head()
# Out:
#    Churn     genero  idoso  parceiro  dependentes  meses_contrato  \
# 0      0   feminino      0         1            1               9
# 1      0  masculino      0         0            0               9
# 2      1  masculino      0         0            0               4
# 3      1  masculino      1         1            0              13
# 4      1   feminino      1         1            0               3
#
#    servico_telefonico multiplas_linhas servico_internet seguranca_online  ...  \
# 0                   1                0              DSL                0  ...
# 1                   1                1              DSL                0  ...
# 2                   1                0     fibra óptica                0  ...
# 3                   1                0     fibra óptica                0  ...
# 4                   1                0     fibra óptica                0  ...
#
#   protecao_dispositivo suporte_tecnico tv_a_cabo streaming_filmes contrato  \
# ...

# %%
dados_normalizados = dados_normalizados.applymap(lambda x: x.lower() if isinstance(x, str) else x)
dados_normalizados
# Out:
# /tmp/ipython-input-28-1951704782.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   dados_normalizados = dados_normalizados.applymap(lambda x: x.lower() if isinstance(x, str) else x)
#       Churn     genero  idoso  parceiro  dependentes  meses_contrato  \
# 0         0   feminino      0         1            1               9
# 1         0  masculino      0         0            0               9
# 2         1  masculino      0         0            0               4
# 3         1  masculino      1         1            0              13
# 4         1   feminino      1         1            0               3
# ...     ...        ...    ...       ...          ...             ...
# 7038      0   feminino      0         0            0              13
# 7039      1  masculino      0         1            0              22
# 7040      0  masculino      0         0            0               2
# ...

# %% [markdown]
# #📊 Carga e análise

# %%
dados_normalizados.describe()
# Out:
#              Churn        idoso     parceiro  dependentes  meses_contrato  \
# count  7043.000000  7043.000000  7043.000000  7043.000000     7043.000000
# mean      0.265370     0.162147     0.483033     0.299588       32.371149
# std       0.441561     0.368612     0.499748     0.458110       24.559481
# min       0.000000     0.000000     0.000000     0.000000        0.000000
# 25%       0.000000     0.000000     0.000000     0.000000        9.000000
# 50%       0.000000     0.000000     0.000000     0.000000       29.000000
# 75%       1.000000     0.000000     1.000000     1.000000       55.000000
# max       1.000000     1.000000     1.000000     1.000000       72.000000
#
#        servico_telefonico  fatura_online  cobranca_mensal  gasto_total  \
# count         7043.000000    7043.000000      7043.000000  7032.000000
# mean             0.903166       0.592219        64.761692  2283.300441
# std              0.295752       0.491457        30.090047  2266.771362
# ...

# %%
cores = ['#67C9E0', '#E0677F']

# %%
import plotly.graph_objects as go

contagem_churn = dados_normalizados['Churn'].value_counts()

fig = go.Figure(data=[go.Pie(
    labels=['Não', 'Sim'],
    values=contagem_churn.values,
    pull=[0.1, 0],
    marker=dict(colors=cores),
    hoverinfo='label+value+percent',
    textinfo='percent'
)])

fig.update_layout(title='Distribuição de Churn na empresa TelecomX',
                  width=800,
                  height=800)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Detalhamento de variáveis - Geral

# %%
from matplotlib.ticker import MultipleLocator
from matplotlib import figure

# %%
contagem = dados_normalizados['meses_contrato'].value_counts().sort_index()
bins = list(range(0, contagem.index.max() + 5, 5))
labels_contrato = [f"{i+1}-{i+5}" for i in bins[:-1]]

contagem_df = contagem.reset_index()
contagem_df.columns = ['meses', 'quantidade']
contagem_df['faixa'] = pd.cut(contagem_df['meses'], bins=bins, labels=labels_contrato, right=True)
agrupado = contagem_df.groupby('faixa')['quantidade'].sum()
# Out:
# /tmp/ipython-input-33-3097798310.py:8: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %%
import numpy as np

cobranca = dados_normalizados['cobranca_mensal'].value_counts().sort_index()

max_cobranca = cobranca.index.max()
bins_cobranca = np.arange(0, max_cobranca + 5, 5)
labels_cobranca = [f"{int(bins_cobranca[i]+0.1)}-{int(bins_cobranca[i+1])}" for i in range(len(bins_cobranca)-1)]


cobranca = cobranca.reset_index()
cobranca.columns = ['meses', 'quantidade']
cobranca['faixa'] = pd.cut(cobranca['meses'], bins=bins_cobranca, labels=labels_cobranca, right=True, include_lowest=True)
agrupado_cobranca = cobranca.groupby('faixa')['quantidade'].sum()
agrupado_cobranca.head()
# Out:
# /tmp/ipython-input-34-1078788363.py:13: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# faixa
# 0-5        0
# 5-10       0
# 10-15      0
# 15-20    656
# 20-25    750
# Name: quantidade, dtype: int64

# %%
gasto_total = dados_normalizados['gasto_total'].value_counts().sort_index()

bins_gasto_total = np.arange(18, 8100, 500)
labels_gasto_total = [f"{int(bins_gasto_total[i]+0.1)}-{int(bins_gasto_total[i+1])}" for i in range(len(bins_gasto_total)-1)]


gasto_total = gasto_total.reset_index()
gasto_total.columns = ['valor', 'qtd_clientes']
gasto_total['faixa'] = pd.cut(gasto_total['valor'], bins=bins_gasto_total, labels=labels_gasto_total, right=True, include_lowest=True)
agrupado_gasto_total = gasto_total.groupby('faixa')['qtd_clientes'].sum()
agrupado_gasto_total
# Out:
# /tmp/ipython-input-35-3680619856.py:10: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# faixa
# 18-518       2032
# 518-1018      887
# 1018-1518     767
# 1518-2018     506
# 2018-2518     354
# 2518-3018     296
# 3018-3518     289
# 3518-4018     266
# 4018-4518     249
# 4518-5018     261
# 5018-5518     203
# 5518-6018     237
# 6018-6518     193
# 6518-7018     170
# 7018-7518     133
# 7518-8018     115
# Name: qtd_clientes, dtype: int64

# %%
contas_diarias = dados_normalizados['contas_diarias'].value_counts().sort_index()

bins_contas_diarias = [0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4]
labels_contas_diarias = [f"{float(bins_contas_diarias[i]+0.1)}-{float(bins_contas_diarias[i+1])}" for i in range(len(bins_contas_diarias)-1)]

contas_diarias = contas_diarias.reset_index()
contas_diarias.columns = ['valor', 'qtd_clientes']
contas_diarias['faixa'] = pd.cut(contas_diarias['valor'], bins=bins_contas_diarias, labels=labels_contas_diarias, right=True, include_lowest=True)
agrupado_contas_diarias = contas_diarias.groupby('faixa')['qtd_clientes'].sum()
agrupado_contas_diarias
# Out:
# /tmp/ipython-input-36-2088075755.py:9: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# faixa
# 0.6-1.0    1659
# 1.1-1.5     387
# 1.6-2.0     883
# 2.1-2.5    1009
# 2.6-3.0    1386
# 3.1-3.5    1214
# 3.6-4.0     505
# Name: qtd_clientes, dtype: int64

# %%
import plotly.express as px
from plotly.subplots import make_subplots

fig = make_subplots(rows=2, cols=5, subplot_titles=['Gênero', 'Idosos', 'Parceiros', 'Dependentes', 'Tempo de contrato', 'Serviço Telefônico', 'Múltiplas Linhas',
                                                    'Serviço de Internet', 'Segurança Online', 'Backup Online'])

fig.add_trace(go.Bar(x=['Feminino', 'Masculino'],
                     y=dados_normalizados['genero'].value_counts(),
                     marker_color='#67C9E0',
                     width=0.4), row=1, col=1)

fig.add_trace(go.Bar(x=['Não', 'Sim'],
                     y=dados_normalizados['idoso'].value_counts(),
                     marker_color='#67C9E0',
                     width=0.4), row=1, col=2)

fig.add_trace(go.Bar(x=['Não', 'Sim'],
                     y=dados_normalizados['parceiro'].value_counts(),
                     marker_color='#67C9E0',
                     width=0.4), row=1, col=3)

fig.add_trace(go.Bar(x=['Não', 'Sim'],
                     y=dados_normalizados['dependentes'].value_counts(),
                     marker_color='#67C9E0',
                     width=0.4), row=1, col=4)

fig.add_trace(go.Bar(x=[0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75],
                     y=agrupado.values,
                     hovertemplate=agrupado.index.astype(str)+', %{y}',
                     marker_color='#67C9E0'), row=1, col=5)

fig.add_trace(go.Bar(x=['Não', 'Sim', 'Sem serviço telêfonico'],
                     y=dados_normalizados['servico_telefonico'].value_counts(),
                     marker_color='#67C9E0',
                     width=0.4), row=2, col=1)

fig.add_trace(go.Bar(x=['Não', 'Sim', 'Sem serviço telêfonico'],
                     y=dados_normalizados['multiplas_linhas'].value_counts(),
                     marker_color='#67C9E0',
                     width=0.4), row=2, col=2)

fig.add_trace(go.Bar(x=['Não', 'Sim', 'Sem serviço de internet'],
                     y=dados_normalizados['servico_internet'].value_counts(),
                     marker_color='#67C9E0',
                     width=0.4), row=2, col=3)

fig.add_trace(go.Bar(x=['Não', 'Sim', 'Sem serviço de internet'],
                     y=dados_normalizados['seguranca_online'].value_counts(),
                     marker_color='#67C9E0',
                     width=0.4), row=2, col=4)

fig.add_trace(go.Bar(x=['Não', 'Sim', 'Sem serviço de internet'],
                     y=dados_normalizados['backup_online'].value_counts(),
                     marker_color='#67C9E0',
                     width=0.4), row=2, col=5)

fig.update_layout(title='Distribuição de clientes por categoria na empresa TelecomX - Geral',
                  xaxis = dict(tickangle=45),
                  width=1400,
                  height=700,
                  font_family='Arial',
                  title_font_color='black',
                  title_font_size=16,
                  font_size=12,
                  showlegend=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = make_subplots(rows=2, cols=5, subplot_titles=['Proteção de Dispositivo', 'Suporte Técnico', 'TV a Cabo', 'Streaming de Filmes', 'Tipo de Contrato', 'Fatura Online',
                                                    'Método de Pagamento', 'Cobrança Mensal', 'Gasto Total', 'Contas Diárias'])

fig.add_trace(go.Bar(x=['Não', 'Sim', 'Sem serviço de Internet'],
                     y=dados_normalizados['protecao_dispositivo'].value_counts(),
                     marker_color='#67C9E0',
                     width=0.4), row=1, col=1)

fig.add_trace(go.Bar(x=['Não', 'Sim', 'Sem serviço de Internet'],
                     y=dados_normalizados['suporte_tecnico'].value_counts(),
                     marker_color='#67C9E0',
                     width=0.4), row=1, col=2)

fig.add_trace(go.Bar(x=['Não', 'Sim', 'Sem serviço de Internet'],
                     y=dados_normalizados['tv_a_cabo'].value_counts(),
                     marker_color='#67C9E0',
                     width=0.4), row=1, col=3)

fig.add_trace(go.Bar(x=['Não', 'Sim', 'Sem serviço de Internet'],
                     y=dados_normalizados['streaming_filmes'].value_counts(),
                     marker_color='#67C9E0',
                     width=0.4), row=1, col=4)

fig.add_trace(go.Bar(x=['Mensal', 'Anual', 'Bienal'],
                     y=dados_normalizados['contrato'].value_counts(),
                     marker_color='#67C9E0',
                     width=0.4), row=1, col=5)

fig.add_trace(go.Bar(x=['Não', 'Sim'],
                     y=dados_normalizados['fatura_online'].value_counts(),
                     marker_color='#67C9E0',
                     width=0.4), row=2, col=1)

fig.add_trace(go.Bar(x=['Cheque', 'Cheque eletrônico', 'Cartão de crédito', 'Transferência Bancária'],
                     y=dados_normalizados['metodo_pagamento'].value_counts(),
                     marker_color='#67C9E0',
                     width=0.4), row=2, col=2)

fig.add_trace(go.Bar(x=list(range(0, 120, 5)),
                     y=agrupado_cobranca.values,
                     marker_color='#67C9E0',
                     hovertemplate=agrupado_cobranca.index.astype(str)+', %{y}'), row=2, col=3)

fig.add_trace(go.Bar(x=list(range(0, 8200, 500)),
                     y=agrupado_gasto_total.values,
                     marker_color='#67C9E0',
                     hovertemplate=agrupado_gasto_total.index.astype(str)+', %{y}'), row=2, col=4)

fig.add_trace(go.Bar(x=[0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4],
                     y=agrupado_contas_diarias.values,
                     marker_color='#67C9E0',
                     hovertemplate=agrupado_contas_diarias.index.astype(str)+', %{y}'), row=2, col=5)

fig.update_layout(title='Distribuição de clientes por categoria na empresa TelecomX - Geral',
                  xaxis = dict(tickangle=45),
                  width=1400,
                  height=700,
                  font_family='Arial',
                  title_font_color='black',
                  title_font_size=16,
                  font_size=12,
                  showlegend=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Detalhamento Variáveis - Churn x No Churn

# %%
dados_churn = dados_normalizados.query('Churn == 1')
dados_no_churn = dados_normalizados.query('Churn == 0')

# %%
#Churn

contagem_churn = dados_churn['meses_contrato'].value_counts().sort_index()
bins_churn = list(range(0, contagem_churn.index.max() + 5, 5))
labels_contrato_churn = [f"{i+1}-{i+5}" for i in bins[:-1]]
contagem_churn = contagem_churn.reset_index()
contagem_churn.columns = ['meses', 'quantidade']
contagem_churn['faixa'] = pd.cut(contagem_churn['meses'], bins=bins_churn, labels=labels_contrato_churn, right=True)
agrupado_churn = contagem_churn.groupby('faixa')['quantidade'].sum()

cobranca_churn = dados_churn['cobranca_mensal'].value_counts().sort_index()
max_cobranca_churn = cobranca_churn.index.max()
bins_cobranca_churn = np.arange(0, max_cobranca_churn + 5, 5)
labels_cobranca_churn = [f"{int(bins_cobranca_churn[i]+0.1)}-{int(bins_cobranca_churn[i+1])}" for i in range(len(bins_cobranca_churn)-1)]
cobranca_churn = cobranca_churn.reset_index()
cobranca_churn.columns = ['meses', 'quantidade']
cobranca_churn['faixa'] = pd.cut(cobranca_churn['meses'], bins=bins_cobranca_churn, labels=labels_cobranca_churn, right=True, include_lowest=True)
agrupado_cobranca_churn = cobranca_churn.groupby('faixa')['quantidade'].sum()

gasto_total_churn = dados_churn['gasto_total'].value_counts().sort_index()
bins_gasto_total_churn = np.arange(18, 8100, 500)
labels_gasto_total_churn = [f"{int(bins_gasto_total_churn[i]+0.1)}-{int(bins_gasto_total_churn[i+1])}" for i in range(len(bins_gasto_total_churn)-1)]
gasto_total_churn = gasto_total_churn.reset_index()
gasto_total_churn.columns = ['valor', 'qtd_clientes']
gasto_total_churn['faixa'] = pd.cut(gasto_total_churn['valor'], bins=bins_gasto_total_churn, labels=labels_gasto_total_churn, right=True, include_lowest=True)
agrupado_gasto_total_churn = gasto_total_churn.groupby('faixa')['qtd_clientes'].sum()

contas_diarias_churn = dados_churn['contas_diarias'].value_counts().sort_index()
bins_contas_diarias_churn = [0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4]
labels_contas_diarias_churn = [f"{float(bins_contas_diarias_churn[i]+0.1)}-{float(bins_contas_diarias_churn[i+1])}" for i in range(len(bins_contas_diarias_churn)-1)]
contas_diarias_churn = contas_diarias_churn.reset_index()
contas_diarias_churn.columns = ['valor', 'qtd_clientes']
contas_diarias_churn['faixa'] = pd.cut(contas_diarias_churn['valor'], bins=bins_contas_diarias_churn, labels=labels_contas_diarias_churn, right=True, include_lowest=True)
agrupado_contas_diarias_churn = contas_diarias_churn.groupby('faixa')['qtd_clientes'].sum()
# Out:
# /tmp/ipython-input-40-3804313740.py:9: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /tmp/ipython-input-40-3804313740.py:18: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /tmp/ipython-input-40-3804313740.py:26: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /tmp/ipython-input-40-3804313740.py:34: FutureWarning:
#
# ...

# %%
#No Churn

contagem_no_churn = dados_no_churn['meses_contrato'].value_counts().sort_index()
bins_no_churn = list(range(0, contagem_no_churn.index.max() + 5, 5))
labels_contrato_no_churn = [f"{i+1}-{i+5}" for i in bins[:-1]]
contagem_no_churn = contagem_no_churn.reset_index()
contagem_no_churn.columns = ['meses', 'quantidade']
contagem_no_churn['faixa'] = pd.cut(contagem_no_churn['meses'], bins=bins_no_churn, labels=labels_contrato_no_churn, right=True)
agrupado_no_churn = contagem_no_churn.groupby('faixa')['quantidade'].sum()

cobranca_no_churn = dados_no_churn['cobranca_mensal'].value_counts().sort_index()
max_cobranca_no_churn = cobranca_no_churn.index.max()
bins_cobranca_no_churn = np.arange(0, max_cobranca_no_churn + 5, 5)
labels_cobranca_no_churn = [f"{int(bins_cobranca_no_churn[i]+0.1)}-{int(bins_cobranca_no_churn[i+1])}" for i in range(len(bins_cobranca_no_churn)-1)]
cobranca_no_churn = cobranca_no_churn.reset_index()
cobranca_no_churn.columns = ['meses', 'quantidade']
cobranca_no_churn['faixa'] = pd.cut(cobranca_no_churn['meses'], bins=bins_cobranca_no_churn, labels=labels_cobranca_no_churn, right=True, include_lowest=True)
agrupado_cobranca_no_churn = cobranca_no_churn.groupby('faixa')['quantidade'].sum()

gasto_total_no_churn = dados_no_churn['gasto_total'].value_counts().sort_index()
bins_gasto_total_no_churn = np.arange(18, 8100, 500)
labels_gasto_total_no_churn = [f"{int(bins_gasto_total_no_churn[i]+0.1)}-{int(bins_gasto_total_no_churn[i+1])}" for i in range(len(bins_gasto_total_no_churn)-1)]
gasto_total_no_churn = gasto_total_no_churn.reset_index()
gasto_total_no_churn.columns = ['valor', 'qtd_clientes']
gasto_total_no_churn['faixa'] = pd.cut(gasto_total_no_churn['valor'], bins=bins_gasto_total_no_churn, labels=labels_gasto_total_no_churn, right=True, include_lowest=True)
agrupado_gasto_total_no_churn = gasto_total_no_churn.groupby('faixa')['qtd_clientes'].sum()

contas_diarias_no_churn = dados_no_churn['contas_diarias'].value_counts().sort_index()
bins_contas_diarias_no_churn = [0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4]
labels_contas_diarias_no_churn = [f"{float(bins_contas_diarias_no_churn[i]+0.1)}-{float(bins_contas_diarias_no_churn[i+1])}" for i in range(len(bins_contas_diarias_no_churn)-1)]
contas_diarias_no_churn = contas_diarias_no_churn.reset_index()
contas_diarias_no_churn.columns = ['valor', 'qtd_clientes']
contas_diarias_no_churn['faixa'] = pd.cut(contas_diarias_no_churn['valor'], bins=bins_contas_diarias_no_churn, labels=labels_contas_diarias_no_churn, right=True, include_lowest=True)
agrupado_contas_diarias_no_churn = contas_diarias_no_churn.groupby('faixa')['qtd_clientes'].sum()
# Out:
# /tmp/ipython-input-41-1800933316.py:9: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /tmp/ipython-input-41-1800933316.py:18: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /tmp/ipython-input-41-1800933316.py:26: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /tmp/ipython-input-41-1800933316.py:34: FutureWarning:
#
# ...

# %%
fig = make_subplots(rows=2, cols=5, subplot_titles=['Gênero', 'Idosos', 'Parceiros', 'Dependentes', 'Tempo de contrato', 'Serviço Telefônico', 'Múltiplas Linhas',
                                                    'Serviço de Internet', 'Segurança Online', 'Backup Online'])

fig.add_trace(go.Bar(x=['Feminino', 'Masculino'],
                     y=dados_churn['genero'].value_counts(),
                     marker_color='#E0677F',
                     width=0.4), row=1, col=1)

fig.add_trace(go.Bar(x=['Não', 'Sim'],
                     y=dados_churn['idoso'].value_counts(),
                     marker_color='#E0677F',
                     width=0.4), row=1, col=2)

fig.add_trace(go.Bar(x=['Não', 'Sim'],
                     y=dados_churn['parceiro'].value_counts(),
                     marker_color='#E0677F',
                     width=0.4), row=1, col=3)

fig.add_trace(go.Bar(x=['Não', 'Sim'],
                     y=dados_churn['dependentes'].value_counts(),
                     marker_color='#E0677F',
                     width=0.4), row=1, col=4)

fig.add_trace(go.Bar(x=[0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75],
                     y=agrupado_churn.values,
                     hovertemplate=agrupado.index.astype(str)+', %{y}',
                     marker_color='#E0677F'), row=1, col=5)

fig.add_trace(go.Bar(x=['Não', 'Sim', 'Sem serviço telêfonico'],
                     y=dados_churn['servico_telefonico'].value_counts(),
                     marker_color='#E0677F',
                     width=0.4), row=2, col=1)

fig.add_trace(go.Bar(x=['Não', 'Sim', 'Sem serviço telêfonico'],
                     y=dados_churn['multiplas_linhas'].value_counts(),
                     marker_color='#E0677F',
                     width=0.4), row=2, col=2)

fig.add_trace(go.Bar(x=['Não', 'Sim', 'Sem serviço de internet'],
                     y=dados_churn['servico_internet'].value_counts(),
                     marker_color='#E0677F',
                     width=0.4), row=2, col=3)

fig.add_trace(go.Bar(x=['Não', 'Sim', 'Sem serviço de internet'],
                     y=dados_churn['seguranca_online'].value_counts(),
                     marker_color='#E0677F',
                     width=0.4), row=2, col=4)

fig.add_trace(go.Bar(x=['Não', 'Sim', 'Sem serviço de internet'],
                     y=dados_churn['backup_online'].value_counts(),
                     marker_color='#E0677F',
                     width=0.4), row=2, col=5)

fig.add_trace(go.Bar(x=['Feminino', 'Masculino'],
                     y=dados_no_churn['genero'].value_counts(),
                     marker_color='#67C9E0',
                     width=0.4), row=1, col=1)

fig.add_trace(go.Bar(x=['Não', 'Sim'],
                     y=dados_no_churn['idoso'].value_counts(),
                     marker_color='#67C9E0',
                     width=0.4), row=1, col=2)

fig.add_trace(go.Bar(x=['Não', 'Sim'],
                     y=dados_no_churn['parceiro'].value_counts(),
                     marker_color='#67C9E0',
                     width=0.4), row=1, col=3)

fig.add_trace(go.Bar(x=['Não', 'Sim'],
                     y=dados_no_churn['dependentes'].value_counts(),
                     marker_color='#67C9E0',
                     width=0.4), row=1, col=4)

fig.add_trace(go.Bar(x=[0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75],
                     y=agrupado_no_churn.values,
                     hovertemplate=agrupado.index.astype(str)+', %{y}',
                     marker_color='#67C9E0'), row=1, col=5)

fig.add_trace(go.Bar(x=['Não', 'Sim', 'Sem serviço telêfonico'],
                     y=dados_no_churn['servico_telefonico'].value_counts(),
                     marker_color='#67C9E0',
                     width=0.4), row=2, col=1)

fig.add_trace(go.Bar(x=['Não', 'Sim', 'Sem serviço telêfonico'],
                     y=dados_no_churn['multiplas_linhas'].value_counts(),
                     marker_color='#67C9E0',
                     width=0.4), row=2, col=2)

fig.add_trace(go.Bar(x=['Não', 'Sim', 'Sem serviço de internet'],
                     y=dados_no_churn['servico_internet'].value_counts(),
                     marker_color='#67C9E0',
                     width=0.4), row=2, col=3)

fig.add_trace(go.Bar(x=['Não', 'Sim', 'Sem serviço de internet'],
                     y=dados_no_churn['seguranca_online'].value_counts(),
                     marker_color='#67C9E0',
                     width=0.4), row=2, col=4)

fig.add_trace(go.Bar(x=['Não', 'Sim', 'Sem serviço de internet'],
                     y=dados_no_churn['backup_online'].value_counts(),
                     marker_color='#67C9E0',
                     width=0.4), row=2, col=5)

fig.update_layout(title='Distribuição de clientes por categoria na empresa TelecomX - Churn x No Churn',
                  xaxis = dict(tickangle=45),
                  barmode='group',
                  width=1400,
                  height=700,
                  font_family='Arial',
                  title_font_color='black',
                  title_font_size=16,
                  font_size=12,
                  showlegend=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = make_subplots(rows=2, cols=5, subplot_titles=['Proteção de Dispositivo', 'Suporte Técnico', 'TV a Cabo', 'Streaming de Filmes', 'Tipo de Contrato', 'Fatura Online',
                                                    'Método de Pagamento', 'Cobrança Mensal', 'Gasto Total', 'Contas Diárias'])

fig.add_trace(go.Bar(x=['Não', 'Sim', 'Sem serviço de Internet'],
                     y=dados_churn['protecao_dispositivo'].value_counts(),
                     marker_color='#E0677F',
                     width=0.4), row=1, col=1)

fig.add_trace(go.Bar(x=['Não', 'Sim', 'Sem serviço de Internet'],
                     y=dados_churn['suporte_tecnico'].value_counts(),
                     marker_color='#E0677F',
                     width=0.4), row=1, col=2)

fig.add_trace(go.Bar(x=['Não', 'Sim', 'Sem serviço de Internet'],
                     y=dados_churn['tv_a_cabo'].value_counts(),
                     marker_color='#E0677F',
                     width=0.4), row=1, col=3)

fig.add_trace(go.Bar(x=['Não', 'Sim', 'Sem serviço de Internet'],
                     y=dados_churn['streaming_filmes'].value_counts(),
                     marker_color='#E0677F',
                     width=0.4), row=1, col=4)

fig.add_trace(go.Bar(x=['Mensal', 'Anual', 'Bienal'],
                     y=dados_churn['contrato'].value_counts(),
                     marker_color='#E0677F',
                     width=0.4), row=1, col=5)

fig.add_trace(go.Bar(x=['Não', 'Sim'],
                     y=dados_churn['fatura_online'].value_counts(),
                     marker_color='#E0677F',
                     width=0.4), row=2, col=1)

fig.add_trace(go.Bar(x=['Cheque', 'Cheque eletrônico', 'Cartão de crédito', 'Transferência Bancária'],
                     y=dados_churn['metodo_pagamento'].value_counts(),
                     marker_color='#E0677F',
                     width=0.4), row=2, col=2)

fig.add_trace(go.Bar(x=list(range(0, 120, 5)),
                     y=agrupado_cobranca_churn.values,
                     marker_color='#E0677F',
                     hovertemplate=agrupado_cobranca_churn.index.astype(str)+', %{y}'), row=2, col=3)

fig.add_trace(go.Bar(x=list(range(0, 8200, 500)),
                     y=agrupado_gasto_total_churn.values,
                     marker_color='#E0677F',
                     hovertemplate=agrupado_gasto_total_churn.index.astype(str)+', %{y}'), row=2, col=4)

fig.add_trace(go.Bar(x=[0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4],
                     y=agrupado_contas_diarias_churn.values,
                     marker_color='#E0677F',
                     hovertemplate=agrupado_contas_diarias_churn.index.astype(str)+', %{y}'), row=2, col=5)

fig.add_trace(go.Bar(x=['Não', 'Sim', 'Sem serviço de Internet'],
                     y=dados_no_churn['protecao_dispositivo'].value_counts(),
                     marker_color='#67C9E0',
                     width=0.4), row=1, col=1)

fig.add_trace(go.Bar(x=['Não', 'Sim', 'Sem serviço de Internet'],
                     y=dados_no_churn['suporte_tecnico'].value_counts(),
                     marker_color='#67C9E0',
                     width=0.4), row=1, col=2)

fig.add_trace(go.Bar(x=['Não', 'Sim', 'Sem serviço de Internet'],
                     y=dados_no_churn['tv_a_cabo'].value_counts(),
                     marker_color='#67C9E0',
                     width=0.4), row=1, col=3)

fig.add_trace(go.Bar(x=['Não', 'Sim', 'Sem serviço de Internet'],
                     y=dados_no_churn['streaming_filmes'].value_counts(),
                     marker_color='#67C9E0',
                     width=0.4), row=1, col=4)

fig.add_trace(go.Bar(x=['Mensal', 'Anual', 'Bienal'],
                     y=dados_no_churn['contrato'].value_counts(),
                     marker_color='#67C9E0',
                     width=0.4), row=1, col=5)

fig.add_trace(go.Bar(x=['Não', 'Sim'],
                     y=dados_no_churn['fatura_online'].value_counts(),
                     marker_color='#67C9E0',
                     width=0.4), row=2, col=1)

fig.add_trace(go.Bar(x=['Cheque', 'Cheque eletrônico', 'Cartão de crédito', 'Transferência Bancária'],
                     y=dados_no_churn['metodo_pagamento'].value_counts(),
                     marker_color='#67C9E0',
                     width=0.4), row=2, col=2)

fig.add_trace(go.Bar(x=list(range(0, 120, 5)),
                     y=agrupado_cobranca_no_churn.values,
                     marker_color='#67C9E0',
                     hovertemplate=agrupado_cobranca_no_churn.index.astype(str)+', %{y}'), row=2, col=3)

fig.add_trace(go.Bar(x=list(range(0, 8200, 500)),
                     y=agrupado_gasto_total_no_churn.values,
                     marker_color='#67C9E0',
                     hovertemplate=agrupado_gasto_total_no_churn.index.astype(str)+', %{y}'), row=2, col=4)

fig.add_trace(go.Bar(x=[0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4],
                     y=agrupado_contas_diarias_no_churn.values,
                     marker_color='#67C9E0',
                     hovertemplate=agrupado_contas_diarias_no_churn.index.astype(str)+', %{y}'), row=2, col=5)

fig.update_layout(title='Distribuição de clientes por categoria na empresa TelecomX - Churn x No Churn',
                  xaxis = dict(tickangle=45),
                  barmode='group',
                  width=1400,
                  height=700,
                  font_family='Arial',
                  title_font_color='black',
                  title_font_size=16,
                  font_size=12,
                  showlegend=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #📄Relatorio Final

# %% [markdown]
# # **Introdução**
#
# O desafio 'TelecomX' tem como objetivo analisar os dados de uma empresa de telecomunicações para identificar os principais fatores que contribuem para a evasão de clientes. No desenvolvimento desse projeto, realizei o processo de ETL (Extract, Transform and Load) dos dados, seguido da criação de visualizações analíticas que possibilitam compreender o perfil dos clientes que mais cancelam os serviços. A partir dos insights obtidos, elaborei recomendações estratégicas que podem ajudar a empresa a reter seus atuais clientes e atrair novos de forma mais eficaz.

# %% [markdown]
# # 🧹**Limpeza e Tratamento dos Dados**
# *   Leitura, normalização e limpeza dos dados: Importei bibliotecas e fiz a leitura do arquivo através da url. Como o arquivo está em JSON houve a necessidade de normalizar o arquivo utilizando a biblioteca request que transforma esses dados em um dataframe, facilitando a análise.
#
# *   Verificando inconsistências: função info() para verificar os tipos de dados do dataframe, isnull() para verificar dados nulos, unique() para verificar os valores atribuídos ao dataframe, duplicate() para verificar dados duplicados, função lambda para entender se existem valores vazios ('') no dataframe.
#
# *   Tratando as inconsistências: alteração dos nomes das colunas para onde houvesse '.' fosse substituído por '_'. Analisei os dados onde a coluna Churn não apresenta valor para verificar se existem padrões nos dados ausentes, verificando que não existe padrão e entendendo que esses dados representam 3% de todo o dataframe optei por excluir essas linhas para conseguir fazer análises mais assertivas sem ser prejudicada por esses dados ausentes. Alterei a coluna 'account.Charges.Total' para float para tratar os valores vazios que possuíam nessa colunas.
#
# *   Outros: remoção da coluna 'customerID'. Reset no index do dataframe, alteração de 'yes' para 1 e 'no' para 0 para melhorar o processamento matemático e criar uma padronização no dataframe. Criação da coluna contas diárias. Renomeei e traduzi os nomes das colunas e os dados no dataframe a fim de tornar os dados mais acessíveis e compreensíveis. Também deixei todas as infos em minúsculas a fim de padronização.

# %% [markdown]
# # **📈 Análise Exploratória dos Dados**
#
#
# Análise da distribuição de evasão através do gráfico de pizza. Entendemos que a evasão de cliente qualifica cerca de 27% dos clientes, um número bem expressivo e preocupante para a empresa.
#
# Após isso decidi verificar, em gráficos simples de barras através de subplots, todas as variáveis de forma geral. Insigths que conseguimos extrair analisando esses gráficos:
#
# * quase 50% dos clientes possuem um parceiro,
# * existem um número muito expressivo de clientes com pouco tempo de contrato(entre 1 e 5 meses),
# * número muito baixo de clientes que usam serviço telefônico,
# * a maior parte dos clientes possuem contrato mensal,
# * a forma de pagamento mais comum é através do cheque.
#
# Da mesma forma que feito anteriormente, uma análise através de gráficos de barras e subplots, porém agora analisando dados de Churn e No Churn lado a lado(vermelho=Churn, azul=No Churn). Insigths que conseguimos extrair analisando dessa forma:
# * clientes que possuem dependentes cancelam menos,
# * índice altíssimo de cancelamento em clientes com poucos meses de contrato (1 a 5 meses),
# * clientes que não possuem serviços adicionais tem mais incidência em cancelamento,
# * maior parte dos clientes que não possui suporte técnico adicional cancelam,
# * altíssimo índice de cancelamentos em contratos mensais,
# * altíssimo índice de cancelamento de clientes que pagam com cheque físico,
# * analisando os gastos totais, clientes que mais cancelam são os que menos gastam.

# %% [markdown]
# # ✍️Conclusões e Insights
#
# Analisando e ligando os fatos podemos concluir que:
#
# * Clientes com contratos mensais e recentes (1 a 5 meses) possuem altíssimo índice de evasão, podendo ser indicativo de problemas na fase inicial de experiência com a empresa e também a flexibilidade do contrato mensal facilita a evasão.
# * Clientes sem serviços adicionais tem maior tendência ao cancelamento (maior índice no suporte técnico).
# * Pagamento por cheque físico também está associado a evasão, enquanto que os meios digitais não têm relação tão forte.
# * Clientes sem dependentes ou parceiros tendem a cancelar mais, indicando que clientes que tenham com quem compartilhar seus benefícios tenham maior chances de permanecer seu contrato com a empresa.
# * Clientes que menos gastam são o que mais cancelam, podendo ter relação com o tempo permanecido na empresa e também com o fato de não obter serviços adicionais.

# %% [markdown]
# # 💡 Recomendações
#
# Após analisar os dados da empresa TelecomX e gerar visualizações que ajudaram a entender melhor o perfil dos clientes, seguem as principais recomendações para que a empresa consiga tratar seu problema com cancelamento e evasão de clientes.
#
# * Procurando atingir clientes com parceiros e dependentes, ofererer planos familiares, que incluam serviços que atendem a toda a família.
# * Incentivar a alteração dos contratos de atuais clientes para contratos de longo prazo e ofertar apenas contrato anuais ou bienais para novos clientes, se possível oferecendo benefícios para quem aderir esses tipos de contrato.
# * Façam pacotes promocionais para adesão de serviços adicionais, se possível focar principalmente no serviço de suporte, pois estes fazem com que fidelize o cliente
# * Incentivar atuais clientes a alterar sua forma de pagamento de cheque físico para algum modo de pagamento digital e ofertar apenas pagamentos digitais para novos clintes.
# * Aumentar os tipos de pagamentos digitais, como PIX e boleto bancário, por exemplo.
# * Aprimorar os primeiros meses de experiência do cliente com onboarding eficaz e suporte proativo nos primeiros meses de contrato, buscando assim maior fidelização.
